# %% [markdown]
# # ECA-DNet: Efficient Channel Attention Dehazing Network
# ## Full Training Pipeline —
# **Datasets Required (Add via + Add Input):**
# 1. `kmljts/reside-6k`
# 2. `balraj98/indoor-training-set-its-residestandard`
# 3. `balraj98/synthetic-objective-testing-set-sots-reside`
#
# **Settings:** GPU P100 | Persistence: Files | Internet: ON

# %%
import os, cv2, json, time, random, warnings, gc, sys
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers, callbacks
from tensorflow.keras.mixed_precision import set_global_policy

warnings.filterwarnings('ignore')
# set_global_policy('mixed_float16')
tf.config.optimizer.set_jit(False) # Enable XLA compilation

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

print(f"TensorFlow : {tf.__version__}")
print(f"GPUs found : {len(gpus)}")
if gpus:
    print(f"GPU name   : {gpus[0].name}")
# print(f"Precision  : {tf.keras.mixed_precision.global_policy().name}")
# Out:
# 2026-05-31 03:17:52.093632: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780197472.279183      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780197472.328489      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780197472.709536      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780197472.709574      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780197472.709576      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780197472.709579      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow : 2.19.0
# GPUs found : 1
# GPU name   : /physical_device:GPU:0

# %%
import os

# Data Configuration
IMG_SIZE         = 256
CHANNELS         = 3

# Architecture
ENC_FILTERS      = [32, 64, 128, 256, 512]
DEC_FILTERS      = [256, 128, 64, 32]
ECA_KERNEL       = 3

# Regularization (NO L2 since AdamW handles weight decay)
SPATIAL_DROP     = 0.05
BOTTLENECK_DROP  = 0.10

# Training Parameters
BATCH_SIZE       = 16
BATCH_SIZE_S3    = 8

# Multi-Stage Epoch Schedule (110 Epochs Total)
LR_S1, EPOCHS_S1, WARMUP_S1 = 1e-3, 60, 5
LR_S2, EPOCHS_S2, WARMUP_S2 = 1e-4, 30, 2
LR_S3, EPOCHS_S3            = 5e-5, 20

PATIENCE_ES      = 15
PATIENCE_LR      = 7
MIN_LR           = 1e-7

#  Loss weights (VGG Perceptual added)++
W_MAE, W_SSIM, W_EDGE, W_FREQ, W_PERCEP = 0.35, 0.20, 0.10, 0.10, 0.25

# Augmentation
AUG_BRIGHTNESS   = 0.08
AUG_NOISE_STD    = 0.01
AUG_CONTRAST     = 0.10

# Paths
SAVE_DIR    = '/kaggle/working'
MODEL_DIR   = f'{SAVE_DIR}/models'
HISTORY_DIR = f'{SAVE_DIR}/history'
PLOT_DIR    = f'{SAVE_DIR}/plots'
METRIC_DIR  = f'{SAVE_DIR}/metrics'
RESULT_DIR  = f'{SAVE_DIR}/results'
LOG_DIR     = f'{SAVE_DIR}/logs'

for d in [MODEL_DIR, HISTORY_DIR, PLOT_DIR, METRIC_DIR, RESULT_DIR, LOG_DIR]:
    os.makedirs(d, exist_ok=True)

print("Configuration loaded")
print(f"  Enc filters : {ENC_FILTERS}")
print(f"  Total epochs: {EPOCHS_S1+EPOCHS_S2+EPOCHS_S3}")
# Out:
# Configuration loaded
#   Enc filters : [32, 64, 128, 256, 512]
#   Total epochs: 110

# %%
#DATASET PATH DETECTION (auto-detects nested folders)

def find_dir(base, candidates):
    for c in candidates:
        p = os.path.join(base, c)
        if os.path.isdir(p) and len(os.listdir(p)) > 0:
            return p
    # Try one level deeper
    if os.path.isdir(base):
        for sub in os.listdir(base):
            sp = os.path.join(base, sub)
            if os.path.isdir(sp):
                for c in candidates:
                    p = os.path.join(sp, c)
                    if os.path.isdir(p) and len(os.listdir(p)) > 0:
                        return p
    return None

R6K = '/kaggle/input/datasets/kmljts/reside-6k/RESIDE-6K'
R6K_TRAIN_HAZY = find_dir(R6K, ['train/hazy','Train/hazy','train/Hazy'])
R6K_TRAIN_GT   = find_dir(R6K, ['train/GT','train/gt','train/clear','Train/GT'])
R6K_TEST_HAZY  = find_dir(R6K, ['test/hazy','Test/hazy','test/Hazy'])
R6K_TEST_GT    = find_dir(R6K, ['test/GT','test/gt','test/clear','Test/GT'])

ITS  = '/kaggle/input/datasets/balraj98/indoor-training-set-its-residestandard'
ITS_HAZY = find_dir(ITS, ['hazy','Hazy','ITS/hazy','data/hazy','train/hazy'])
ITS_GT   = find_dir(ITS, ['clear','Clear','GT','gt','clean','ITS/clear','data/clear','train/clear','train/GT'])

SOTS = '/kaggle/input/datasets/balraj98/synthetic-objective-testing-set-sots-reside'
SOTS_IN_HAZY  = find_dir(SOTS, ['indoor/hazy','SOTS/indoor/hazy','sots/indoor/hazy'])
SOTS_IN_GT    = find_dir(SOTS, ['indoor/clear','indoor/gt','indoor/clear','SOTS/indoor/GT','SOTS/indoor/gt'])
SOTS_OUT_HAZY = find_dir(SOTS, ['outdoor/hazy','SOTS/outdoor/hazy','sots/outdoor/hazy'])
SOTS_OUT_GT   = find_dir(SOTS, ['outdoor/clear','outdoor/Clear','outdoor/clear','SOTS/outdoor/GT'])

print("="*65)
print("DATASET PATH VERIFICATION")
print("="*65)
for name, path in [
    ('R6K Train Hazy', R6K_TRAIN_HAZY), ('R6K Train GT', R6K_TRAIN_GT),
    ('R6K Test Hazy',  R6K_TEST_HAZY),  ('R6K Test GT',  R6K_TEST_GT),
    ('ITS Hazy',       ITS_HAZY),        ('ITS GT',       ITS_GT),
    ('SOTS In Hazy',   SOTS_IN_HAZY),   ('SOTS In GT',   SOTS_IN_GT),
    ('SOTS Out Hazy',  SOTS_OUT_HAZY),  ('SOTS Out GT',  SOTS_OUT_GT),
]:
    if path:
        n = len(os.listdir(path))
        print(f"  OK  {name:<18} {path}  [{n} files]")
    else:
        print(f"  XX  {name:<18} NOT FOUND")
print("="*65)
# Out:
# =================================================================
# DATASET PATH VERIFICATION
# =================================================================
#   OK  R6K Train Hazy     /kaggle/input/datasets/kmljts/reside-6k/RESIDE-6K/train/hazy  [6000 files]
#   OK  R6K Train GT       /kaggle/input/datasets/kmljts/reside-6k/RESIDE-6K/train/GT  [6000 files]
#   OK  R6K Test Hazy      /kaggle/input/datasets/kmljts/reside-6k/RESIDE-6K/test/hazy  [1000 files]
#   OK  R6K Test GT        /kaggle/input/datasets/kmljts/reside-6k/RESIDE-6K/test/GT  [1000 files]
#   OK  ITS Hazy           /kaggle/input/datasets/balraj98/indoor-training-set-its-residestandard/hazy  [13990 files]
#   OK  ITS GT             /kaggle/input/datasets/balraj98/indoor-training-set-its-residestandard/clear  [1399 files]
#   OK  SOTS In Hazy       /kaggle/input/datasets/balraj98/synthetic-objective-testing-set-sots-reside/indoor/hazy  [500 files]
#   OK  SOTS In GT         /kaggle/input/datasets/balraj98/synthetic-objective-testing-set-sots-reside/indoor/clear  [50 files]
#   OK  SOTS Out Hazy      /kaggle/input/datasets/balraj98/synthetic-objective-testing-set-sots-reside/outdoor/hazy  [500 files]
#   OK  SOTS Out GT        /kaggle/input/datasets/balraj98/synthetic-objective-testing-set-sots-reside/outdoor/clear  [492 files]
# =================================================================

# %%
def preprocess_hazy(img):
    img = np.power(np.clip(img, 0, 1), 0.9).astype(np.float32)
    for c in range(3):
        lo, hi = img[:,:,c].min(), img[:,:,c].max()
        if hi > lo + 1e-6:
            img[:,:,c] = (img[:,:,c] - lo) / (hi - lo)
    return np.clip(img, 0, 1).astype(np.float32)

def load_image_pair(hazy_path, gt_path, size=IMG_SIZE):
    hazy = cv2.imread(str(hazy_path))
    gt   = cv2.imread(str(gt_path))
    if hazy is None or gt is None:
        return None, None
    hazy = cv2.cvtColor(hazy, cv2.COLOR_BGR2RGB)
    gt   = cv2.cvtColor(gt,   cv2.COLOR_BGR2RGB)
    hazy = cv2.resize(hazy, (size, size)).astype(np.float32) / 255.0
    gt   = cv2.resize(gt,   (size, size)).astype(np.float32) / 255.0
    hazy = preprocess_hazy(hazy)
    return hazy, gt

def get_gt_path(hazy_name, gt_dir):
    stem = Path(hazy_name).stem
    candidates = [stem, stem.split('_')[0], stem.replace('_hazy',''),
                  stem.replace('_fog',''), stem.replace('_synthetic','')]
    for cand in candidates:
        for ext in ['.png','.jpg','.jpeg','.PNG','.JPG','.bmp']:
            p = os.path.join(gt_dir, cand + ext)
            if os.path.exists(p):
                return p
    return None

def collect_pairs(hazy_dir, gt_dir, tag='', limit=None):
    if not hazy_dir or not gt_dir:
        return []
    files = sorted(os.listdir(hazy_dir))
    if limit:
        files = files[:limit]
    pairs = []
    for hf in files:
        if not hf.lower().endswith(('.png','.jpg','.jpeg','.bmp')):
            continue
        gp = get_gt_path(hf, gt_dir)
        if gp:
            pairs.append((os.path.join(hazy_dir, hf), gp))
    skip = len(files) - len(pairs)
    print(f"  {tag:<22}: {len(pairs):>5} pairs  ({skip} skipped)")
    return pairs

print("Collecting training pairs...")
r6k_pairs = collect_pairs(R6K_TRAIN_HAZY, R6K_TRAIN_GT, 'RESIDE-6K train')
its_pairs  = collect_pairs(ITS_HAZY, ITS_GT, 'ITS indoor')

all_train = r6k_pairs + its_pairs
random.shuffle(all_train)
print(f"\nTotal training pairs : {len(all_train)}")

hazy_paths = [p[0] for p in all_train]
gt_paths   = [p[1] for p in all_train]

tr_h, va_h, tr_g, va_g = train_test_split(
    hazy_paths, gt_paths, test_size=0.10, random_state=SEED, shuffle=True)
print(f"Train : {len(tr_h)}  |  Val : {len(va_h)}")
# Out:
# Collecting training pairs...
#   RESIDE-6K train       :  6000 pairs  (0 skipped)
#   ITS indoor            : 13990 pairs  (0 skipped)
#
# Total training pairs : 19990
# Train : 17991  |  Val : 1999

# %%
def load_pair_tf(hazy_path, gt_path):
    def _py_load(hp, gp):
        hp = hp.numpy().decode('utf-8')
        gp = gp.numpy().decode('utf-8')
        h, g = load_image_pair(hp, gp)
        if h is None:
            h = np.zeros((IMG_SIZE, IMG_SIZE, 3), np.float32)
            g = np.zeros((IMG_SIZE, IMG_SIZE, 3), np.float32)
        return h, g
    hazy, gt = tf.py_function(_py_load, [hazy_path, gt_path], [tf.float32, tf.float32])
    hazy.set_shape([IMG_SIZE, IMG_SIZE, 3])
    gt.set_shape([IMG_SIZE, IMG_SIZE, 3])
    return hazy, gt

def augment_pair(hazy, gt):
    # Spatial (both)
    do_h = tf.random.uniform(()) > 0.5
    hazy = tf.cond(do_h, lambda: tf.image.flip_left_right(hazy), lambda: hazy)
    gt   = tf.cond(do_h, lambda: tf.image.flip_left_right(gt),   lambda: gt)
    do_v = tf.random.uniform(()) > 0.5
    hazy = tf.cond(do_v, lambda: tf.image.flip_up_down(hazy), lambda: hazy)
    gt   = tf.cond(do_v, lambda: tf.image.flip_up_down(gt),   lambda: gt)
    k = tf.random.uniform((), 0, 4, dtype=tf.int32)
    hazy = tf.image.rot90(hazy, k)
    gt   = tf.image.rot90(gt, k)
    # Photometric (hazy only)
    hazy = tf.image.random_brightness(hazy, max_delta=AUG_BRIGHTNESS)
    hazy = tf.image.random_contrast(hazy, 1-AUG_CONTRAST, 1+AUG_CONTRAST)
    noise = tf.random.normal(tf.shape(hazy), stddev=AUG_NOISE_STD)
    hazy = hazy + noise
    hazy = tf.clip_by_value(hazy, 0.0, 1.0)
    gt   = tf.clip_by_value(gt, 0.0, 1.0)
    return hazy, gt

def build_dataset(hazy_list, gt_list, augment=True, batch=BATCH_SIZE, shuffle=True, cache_ds=False):
    ds = tf.data.Dataset.from_tensor_slices((hazy_list, gt_list))
    if shuffle:
        ds = ds.shuffle(min(len(hazy_list), 3000), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(load_pair_tf, num_parallel_calls=tf.data.AUTOTUNE)
    if cache_ds:
        ds = ds.cache()
    if augment:
        ds = ds.map(augment_pair, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch, drop_remainder=False)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

print("Building tf.data pipelines...")
train_ds = build_dataset(tr_h, tr_g, augment=True, batch=BATCH_SIZE)
val_ds   = build_dataset(va_h, va_g, augment=False, batch=BATCH_SIZE, shuffle=False, cache_ds=True)

STEPS_PER_EPOCH = len(tr_h) // BATCH_SIZE
VAL_STEPS = len(va_h) // BATCH_SIZE
print(f"Train steps/epoch : {STEPS_PER_EPOCH}")
print(f"Val   steps/epoch : {VAL_STEPS}")

for hb, gb in train_ds.take(1):
    print(f"Hazy batch : {hb.shape}  [{hb.numpy().min():.3f}, {hb.numpy().max():.3f}]")
    print(f"GT   batch : {gb.shape}  [{gb.numpy().min():.3f}, {gb.numpy().max():.3f}]")
# Out:
# Building tf.data pipelines...
# I0000 00:00:1780197605.664486      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Train steps/epoch : 1124
# Val   steps/epoch : 124
# 2026-05-31 03:20:07.577419: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_9}}
# Hazy batch : (16, 256, 256, 3)  [0.000, 1.000]
# GT   batch : (16, 256, 256, 3)  [0.000, 1.000]

# %% [markdown]
# ## Model Architecture — Building Blocks

# %%
class ECABlock(layers.Layer):
    def __init__(self, kernel_size=3, **kwargs):
        super().__init__(**kwargs)
        self.kernel_size = kernel_size
    def build(self, input_shape):
        self.channels = input_shape[-1]
        self.conv = layers.Conv1D(1, self.kernel_size, padding='same', use_bias=False)
        self.gap = layers.GlobalAveragePooling2D()
    def call(self, x):
        # x: (B, H, W, C)
        B = tf.shape(x)[0]
        gap = self.gap(x)                                    # (B, C)
        gap = tf.reshape(gap, [B, self.channels, 1])         # (B, C, 1) — channels as sequence
        attn = tf.sigmoid(self.conv(gap))                    # (B, C, 1) — Conv1D slides across channels
        attn = tf.reshape(attn, [B, 1, 1, self.channels])   # (B, 1, 1, C)
        return x * attn                                      # (B, H, W, C) * (B, 1, 1, C) → broadcasts
    def get_config(self):
        cfg = super().get_config()
        cfg['kernel_size'] = self.kernel_size
        return cfg

# ← NEW: Pixel Attention (spatial attention — learns WHERE to focus)
class PixelAttention(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
    def build(self, input_shape):
        C = input_shape[-1]
        self.conv1 = layers.Conv2D(max(8, C // 4), 1, padding='same', use_bias=False)
        self.conv2 = layers.Conv2D(1, 1, padding='same', activation='sigmoid')
    def call(self, x):
        attn = tf.nn.relu(self.conv1(x))
        attn = self.conv2(attn)                              # (B, H, W, 1)
        return x * attn
    def get_config(self):
        return super().get_config()

class PhysicsCorrectionLayer(layers.Layer):
    def __init__(self, eps=0.1, blend=0.08, **kwargs):
        super().__init__(**kwargs)
        self.eps = eps
        self.blend = blend
    def call(self, inputs):
        img, A, t = inputs
        # img: (B,H,W,3), A: (B,3), t: (B,H,W,1)
        A_bc = tf.reshape(A, [-1, 1, 1, 3])                 # (B,1,1,3)
        A_bc = tf.broadcast_to(A_bc, tf.shape(img))          # (B,H,W,3)
        t_bc = tf.broadcast_to(t, tf.shape(img))             # (B,H,W,3)
        j = (img - A_bc) / (t_bc + self.eps) + A_bc          # (B,H,W,3)
        j = tf.clip_by_value(j, 0.0, 1.0)
        return img * (1 - self.blend) + j * self.blend        # (B,H,W,3)
    def get_config(self):
        cfg = super().get_config()
        cfg.update({'eps': self.eps, 'blend': self.blend})
        return cfg

def dws_conv_block(x, filters, kernel_size=3, strides=1):
    # (B,H,W,Cin) → DepthwiseConv → (B,H,W,Cin) → 1x1 Conv → (B,H,W,filters)
    x = layers.DepthwiseConv2D(kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu6')(x)
    x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu6')(x)
    return x

def residual_block(x, filters, use_eca=True, drop_rate=SPATIAL_DROP):
    skip = x
    if x.shape[-1] != filters:
        skip = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
        skip = layers.BatchNormalization()(skip)
    x = dws_conv_block(x, filters)
    x = dws_conv_block(x, filters)
    if use_eca:
        x = ECABlock(kernel_size=ECA_KERNEL)(x)
        x = PixelAttention()(x)                              # ← NEW: spatial attention after ECA
    if drop_rate > 0:
        x = layers.SpatialDropout2D(drop_rate)(x)
    x = layers.Add()([x, skip])
    return x

def encoder_block(x, filters):
    x = residual_block(x, filters, use_eca=True, drop_rate=SPATIAL_DROP)
    skip = x
    x = layers.MaxPooling2D(2)(x)
    return x, skip

def decoder_block(x, skip, filters):
    x = layers.UpSampling2D(2, interpolation='bilinear')(x)
    x = layers.Concatenate()([x, skip])
    x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu6')(x)
    x = residual_block(x, filters, use_eca=True, drop_rate=SPATIAL_DROP/2)
    return x

print("Building blocks defined (Dual Attention: ECA + PixelAttention)")
# Out:
# Building blocks defined (Dual Attention: ECA + PixelAttention)

# %% [markdown]
# ## Full ECA-LDNet Architecture

# %%
def build_eca_ldnet(img_size=IMG_SIZE):
    inputs = layers.Input(shape=(img_size, img_size, CHANNELS), name='hazy_input')

    # ENCODER
    x, skip1 = encoder_block(inputs, ENC_FILTERS[0])  # skip1=256x256x32, x=128x128x32
    x, skip2 = encoder_block(x, ENC_FILTERS[1])       # skip2=128x128x64, x=64x64x64
    x, skip3 = encoder_block(x, ENC_FILTERS[2])       # skip3=64x64x128,  x=32x32x128
    x, skip4 = encoder_block(x, ENC_FILTERS[3])       # skip4=32x32x256,  x=16x16x256

    # BOTTLENECK (16x16x512, NO MaxPool)
    x = dws_conv_block(x, ENC_FILTERS[4])              # 16x16x512
    x = residual_block(x, ENC_FILTERS[4], use_eca=True, drop_rate=0)
    x = layers.Dropout(BOTTLENECK_DROP)(x)
    bottleneck = x                                      # 16x16x512

    # PHYSICS GUIDANCE MODULE
    A = layers.GlobalAveragePooling2D()(bottleneck)     # (512,)
    A = layers.Dense(64, activation='relu')(A)
    A = layers.Dropout(0.1)(A)
    A = layers.Dense(32, activation='relu')(A)
    A = layers.Dense(3, activation='sigmoid', dtype='float32', name='atm_light')(A)  # (3,)

    t = layers.Conv2D(32, 1, padding='same')(bottleneck)
    t = layers.BatchNormalization()(t)
    t = layers.Activation('relu')(t)
    t = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32', padding='same', name='transmission')(t)  # 16x16x1

    t_16 = layers.UpSampling2D(2, interpolation='bilinear')(t)   # 32x32x1
    t_32 = layers.UpSampling2D(4, interpolation='bilinear')(t)   # 64x64x1

    # DECODER with physics attention
    x = decoder_block(x, skip4, DEC_FILTERS[0])        # Up 16→32, cat skip4(32x32x256) → 32x32x256
    hm16 = 1.0 - t_16                                  # 32x32x1
    x = layers.Multiply(name='phys_d4')([x, hm16])     # 32x32x256 * 32x32x1 → broadcasts

    x = decoder_block(x, skip3, DEC_FILTERS[1])        # Up 32→64, cat skip3(64x64x128) → 64x64x128
    hm32 = 1.0 - t_32                                  # 64x64x1
    x = layers.Multiply(name='phys_d3')([x, hm32])     # 64x64x128 * 64x64x1 → broadcasts

    x = decoder_block(x, skip2, DEC_FILTERS[2])        # Up 64→128, cat skip2(128x128x64) → 128x128x64
    x = decoder_block(x, skip1, DEC_FILTERS[3])        # Up 128→256, cat skip1(256x256x32) → 256x256x32

    # Final refinement (NO extra UpSampling)
    x = dws_conv_block(x, 16)                           # 256x256x16

    # OUTPUT
    raw = layers.Conv2D(3, 1, padding='same', use_bias=False, dtype='float32', name='raw_conv')(x)  # 256x256x3
    raw = layers.Activation('sigmoid', dtype='float32', name='raw_sigmoid')(raw)                     # 256x256x3

    t_full = layers.UpSampling2D(img_size // 16, interpolation='bilinear', name='t_full')(t)  # 16*16=256x256x1
    output = PhysicsCorrectionLayer(eps=0.1, blend=0.08, dtype='float32', name='physics_output')([raw, A, t_full])  # 256x256x3

    return Model(inputs=inputs, outputs=output, name='ECA_LDNet')

tf.keras.backend.clear_session()
model = build_eca_ldnet()
total_params = model.count_params()
print(f"\n{'='*60}")
print(f"ECA-LDNet — {total_params:,} params ({total_params/1e6:.3f}M)")
print(f"{'='*60}")
model.summary(line_length=100)

with open(f'{METRIC_DIR}/model_summary.txt', 'w') as f:
    model.summary(print_fn=lambda s: f.write(s+'\n'))
    f.write(f'\nTotal: {total_params:,} ({total_params/1e6:.3f}M)\n')
# Out:
# ============================================================
# ECA-LDNet — 1,481,871 params (1.482M)
# ============================================================
# Model: "ECA_LDNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ hazy_input (InputLayer)     │ (None, 256, 256, 3)     │              0 │ -                       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d            │ (None, 256, 256, 3)     │             27 │ hazy_input[0][0]        │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_1       │ (None, 256, 256, 3)     │             12 │ depthwise_conv2d[0][0]  │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation (Activation)     │ (None, 256, 256, 3)     │              0 │ batch_normalization_1[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_1 (Conv2D)           │ (None, 256, 256, 32)    │             96 │ activation[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_2       │ (None, 256, 256, 32)    │            128 │ conv2d_1[0][0]          │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_1 (Activation)   │ (None, 256, 256, 32)    │              0 │ batch_normalization_2[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_1          │ (None, 256, 256, 32)    │            288 │ activation_1[0][0]      │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_3       │ (None, 256, 256, 32)    │            128 │ depthwise_conv2d_1[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_2 (Activation)   │ (None, 256, 256, 32)    │              0 │ batch_normalization_3[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_2 (Conv2D)           │ (None, 256, 256, 32)    │          1,024 │ activation_2[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_4       │ (None, 256, 256, 32)    │            128 │ conv2d_2[0][0]          │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_3 (Activation)   │ (None, 256, 256, 32)    │              0 │ batch_normalization_4[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block (ECABlock)        │ (None, 256, 256, 32)    │              3 │ activation_3[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention             │ (None, 256, 256, 32)    │            265 │ eca_block[0][0]         │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d (Conv2D)             │ (None, 256, 256, 32)    │             96 │ hazy_input[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d           │ (None, 256, 256, 32)    │              0 │ pixel_attention[0][0]   │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization         │ (None, 256, 256, 32)    │            128 │ conv2d[0][0]            │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add (Add)                   │ (None, 256, 256, 32)    │              0 │ spatial_dropout2d[0][0… │
# │                             │                         │                │ batch_normalization[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ max_pooling2d               │ (None, 128, 128, 32)    │              0 │ add[0][0]               │
# │ (MaxPooling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_2          │ (None, 128, 128, 32)    │            288 │ max_pooling2d[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_6       │ (None, 128, 128, 32)    │            128 │ depthwise_conv2d_2[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_4 (Activation)   │ (None, 128, 128, 32)    │              0 │ batch_normalization_6[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_6 (Conv2D)           │ (None, 128, 128, 64)    │          2,048 │ activation_4[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_7       │ (None, 128, 128, 64)    │            256 │ conv2d_6[0][0]          │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_5 (Activation)   │ (None, 128, 128, 64)    │              0 │ batch_normalization_7[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_3          │ (None, 128, 128, 64)    │            576 │ activation_5[0][0]      │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_8       │ (None, 128, 128, 64)    │            256 │ depthwise_conv2d_3[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_6 (Activation)   │ (None, 128, 128, 64)    │              0 │ batch_normalization_8[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_7 (Conv2D)           │ (None, 128, 128, 64)    │          4,096 │ activation_6[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_9       │ (None, 128, 128, 64)    │            256 │ conv2d_7[0][0]          │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_7 (Activation)   │ (None, 128, 128, 64)    │              0 │ batch_normalization_9[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_1 (ECABlock)      │ (None, 128, 128, 64)    │              3 │ activation_7[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_1           │ (None, 128, 128, 64)    │          1,041 │ eca_block_1[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_5 (Conv2D)           │ (None, 128, 128, 64)    │          2,048 │ max_pooling2d[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d_1         │ (None, 128, 128, 64)    │              0 │ pixel_attention_1[0][0] │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_5       │ (None, 128, 128, 64)    │            256 │ conv2d_5[0][0]          │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_1 (Add)                 │ (None, 128, 128, 64)    │              0 │ spatial_dropout2d_1[0]… │
# │                             │                         │                │ batch_normalization_5[… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ max_pooling2d_1             │ (None, 64, 64, 64)      │              0 │ add_1[0][0]             │
# │ (MaxPooling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_4          │ (None, 64, 64, 64)      │            576 │ max_pooling2d_1[0][0]   │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_11      │ (None, 64, 64, 64)      │            256 │ depthwise_conv2d_4[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_8 (Activation)   │ (None, 64, 64, 64)      │              0 │ batch_normalization_11… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_11 (Conv2D)          │ (None, 64, 64, 128)     │          8,192 │ activation_8[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_12      │ (None, 64, 64, 128)     │            512 │ conv2d_11[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_9 (Activation)   │ (None, 64, 64, 128)     │              0 │ batch_normalization_12… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_5          │ (None, 64, 64, 128)     │          1,152 │ activation_9[0][0]      │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_13      │ (None, 64, 64, 128)     │            512 │ depthwise_conv2d_5[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_10 (Activation)  │ (None, 64, 64, 128)     │              0 │ batch_normalization_13… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_12 (Conv2D)          │ (None, 64, 64, 128)     │         16,384 │ activation_10[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_14      │ (None, 64, 64, 128)     │            512 │ conv2d_12[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_11 (Activation)  │ (None, 64, 64, 128)     │              0 │ batch_normalization_14… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_2 (ECABlock)      │ (None, 64, 64, 128)     │              3 │ activation_11[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_2           │ (None, 64, 64, 128)     │          4,129 │ eca_block_2[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_10 (Conv2D)          │ (None, 64, 64, 128)     │          8,192 │ max_pooling2d_1[0][0]   │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d_2         │ (None, 64, 64, 128)     │              0 │ pixel_attention_2[0][0] │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_10      │ (None, 64, 64, 128)     │            512 │ conv2d_10[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_2 (Add)                 │ (None, 64, 64, 128)     │              0 │ spatial_dropout2d_2[0]… │
# │                             │                         │                │ batch_normalization_10… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ max_pooling2d_2             │ (None, 32, 32, 128)     │              0 │ add_2[0][0]             │
# │ (MaxPooling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_6          │ (None, 32, 32, 128)     │          1,152 │ max_pooling2d_2[0][0]   │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_16      │ (None, 32, 32, 128)     │            512 │ depthwise_conv2d_6[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_12 (Activation)  │ (None, 32, 32, 128)     │              0 │ batch_normalization_16… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_16 (Conv2D)          │ (None, 32, 32, 256)     │         32,768 │ activation_12[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_17      │ (None, 32, 32, 256)     │          1,024 │ conv2d_16[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_13 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_17… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_7          │ (None, 32, 32, 256)     │          2,304 │ activation_13[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_18      │ (None, 32, 32, 256)     │          1,024 │ depthwise_conv2d_7[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_14 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_18… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_17 (Conv2D)          │ (None, 32, 32, 256)     │         65,536 │ activation_14[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_19      │ (None, 32, 32, 256)     │          1,024 │ conv2d_17[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_15 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_19… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_3 (ECABlock)      │ (None, 32, 32, 256)     │              3 │ activation_15[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_3           │ (None, 32, 32, 256)     │         16,449 │ eca_block_3[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_15 (Conv2D)          │ (None, 32, 32, 256)     │         32,768 │ max_pooling2d_2[0][0]   │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d_3         │ (None, 32, 32, 256)     │              0 │ pixel_attention_3[0][0] │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_15      │ (None, 32, 32, 256)     │          1,024 │ conv2d_15[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_3 (Add)                 │ (None, 32, 32, 256)     │              0 │ spatial_dropout2d_3[0]… │
# │                             │                         │                │ batch_normalization_15… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ max_pooling2d_3             │ (None, 16, 16, 256)     │              0 │ add_3[0][0]             │
# │ (MaxPooling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_8          │ (None, 16, 16, 256)     │          2,304 │ max_pooling2d_3[0][0]   │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_20      │ (None, 16, 16, 256)     │          1,024 │ depthwise_conv2d_8[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_16 (Activation)  │ (None, 16, 16, 256)     │              0 │ batch_normalization_20… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_20 (Conv2D)          │ (None, 16, 16, 512)     │        131,072 │ activation_16[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_21      │ (None, 16, 16, 512)     │          2,048 │ conv2d_20[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_17 (Activation)  │ (None, 16, 16, 512)     │              0 │ batch_normalization_21… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_9          │ (None, 16, 16, 512)     │          4,608 │ activation_17[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_22      │ (None, 16, 16, 512)     │          2,048 │ depthwise_conv2d_9[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_18 (Activation)  │ (None, 16, 16, 512)     │              0 │ batch_normalization_22… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_21 (Conv2D)          │ (None, 16, 16, 512)     │        262,144 │ activation_18[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_23      │ (None, 16, 16, 512)     │          2,048 │ conv2d_21[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_19 (Activation)  │ (None, 16, 16, 512)     │              0 │ batch_normalization_23… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_10         │ (None, 16, 16, 512)     │          4,608 │ activation_19[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_24      │ (None, 16, 16, 512)     │          2,048 │ depthwise_conv2d_10[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_20 (Activation)  │ (None, 16, 16, 512)     │              0 │ batch_normalization_24… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_22 (Conv2D)          │ (None, 16, 16, 512)     │        262,144 │ activation_20[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_25      │ (None, 16, 16, 512)     │          2,048 │ conv2d_22[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_21 (Activation)  │ (None, 16, 16, 512)     │              0 │ batch_normalization_25… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_4 (ECABlock)      │ (None, 16, 16, 512)     │              3 │ activation_21[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_4           │ (None, 16, 16, 512)     │         65,665 │ eca_block_4[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_4 (Add)                 │ (None, 16, 16, 512)     │              0 │ pixel_attention_4[0][0… │
# │                             │                         │                │ activation_17[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dropout (Dropout)           │ (None, 16, 16, 512)     │              0 │ add_4[0][0]             │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ up_sampling2d_2             │ (None, 32, 32, 512)     │              0 │ dropout[0][0]           │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ concatenate (Concatenate)   │ (None, 32, 32, 768)     │              0 │ up_sampling2d_2[0][0],  │
# │                             │                         │                │ add_3[0][0]             │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_26 (Conv2D)          │ (None, 32, 32, 256)     │        196,608 │ concatenate[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_27      │ (None, 32, 32, 256)     │          1,024 │ conv2d_26[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_23 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_27… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_11         │ (None, 32, 32, 256)     │          2,304 │ activation_23[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_28      │ (None, 32, 32, 256)     │          1,024 │ depthwise_conv2d_11[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_24 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_28… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_27 (Conv2D)          │ (None, 32, 32, 256)     │         65,536 │ activation_24[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_29      │ (None, 32, 32, 256)     │          1,024 │ conv2d_27[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_25 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_29… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_12         │ (None, 32, 32, 256)     │          2,304 │ activation_25[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_30      │ (None, 32, 32, 256)     │          1,024 │ depthwise_conv2d_12[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_26 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_30… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_28 (Conv2D)          │ (None, 32, 32, 256)     │         65,536 │ activation_26[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_31      │ (None, 32, 32, 256)     │          1,024 │ conv2d_28[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_25 (Conv2D)          │ (None, 16, 16, 32)      │         16,416 │ dropout[0][0]           │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_27 (Activation)  │ (None, 32, 32, 256)     │              0 │ batch_normalization_31… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_26      │ (None, 16, 16, 32)      │            128 │ conv2d_25[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_5 (ECABlock)      │ (None, 32, 32, 256)     │              3 │ activation_27[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_22 (Activation)  │ (None, 16, 16, 32)      │              0 │ batch_normalization_26… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_5           │ (None, 32, 32, 256)     │         16,449 │ eca_block_5[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ transmission (Conv2D)       │ (None, 16, 16, 1)       │             33 │ activation_22[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d_4         │ (None, 32, 32, 256)     │              0 │ pixel_attention_5[0][0] │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ up_sampling2d               │ (None, 32, 32, 1)       │              0 │ transmission[0][0]      │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_5 (Add)                 │ (None, 32, 32, 256)     │              0 │ spatial_dropout2d_4[0]… │
# │                             │                         │                │ activation_23[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ subtract (Subtract)         │ (None, 32, 32, 1)       │              0 │ up_sampling2d[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ phys_d4 (Multiply)          │ (None, 32, 32, 256)     │              0 │ add_5[0][0],            │
# │                             │                         │                │ subtract[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ up_sampling2d_3             │ (None, 64, 64, 256)     │              0 │ phys_d4[0][0]           │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ concatenate_1 (Concatenate) │ (None, 64, 64, 384)     │              0 │ up_sampling2d_3[0][0],  │
# │                             │                         │                │ add_2[0][0]             │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_31 (Conv2D)          │ (None, 64, 64, 128)     │         49,152 │ concatenate_1[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_32      │ (None, 64, 64, 128)     │            512 │ conv2d_31[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_28 (Activation)  │ (None, 64, 64, 128)     │              0 │ batch_normalization_32… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_13         │ (None, 64, 64, 128)     │          1,152 │ activation_28[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_33      │ (None, 64, 64, 128)     │            512 │ depthwise_conv2d_13[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_29 (Activation)  │ (None, 64, 64, 128)     │              0 │ batch_normalization_33… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_32 (Conv2D)          │ (None, 64, 64, 128)     │         16,384 │ activation_29[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_34      │ (None, 64, 64, 128)     │            512 │ conv2d_32[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_30 (Activation)  │ (None, 64, 64, 128)     │              0 │ batch_normalization_34… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_14         │ (None, 64, 64, 128)     │          1,152 │ activation_30[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_35      │ (None, 64, 64, 128)     │            512 │ depthwise_conv2d_14[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_31 (Activation)  │ (None, 64, 64, 128)     │              0 │ batch_normalization_35… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_33 (Conv2D)          │ (None, 64, 64, 128)     │         16,384 │ activation_31[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_36      │ (None, 64, 64, 128)     │            512 │ conv2d_33[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_32 (Activation)  │ (None, 64, 64, 128)     │              0 │ batch_normalization_36… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_6 (ECABlock)      │ (None, 64, 64, 128)     │              3 │ activation_32[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_6           │ (None, 64, 64, 128)     │          4,129 │ eca_block_6[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d_5         │ (None, 64, 64, 128)     │              0 │ pixel_attention_6[0][0] │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ up_sampling2d_1             │ (None, 64, 64, 1)       │              0 │ transmission[0][0]      │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_6 (Add)                 │ (None, 64, 64, 128)     │              0 │ spatial_dropout2d_5[0]… │
# │                             │                         │                │ activation_28[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ subtract_1 (Subtract)       │ (None, 64, 64, 1)       │              0 │ up_sampling2d_1[0][0]   │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ phys_d3 (Multiply)          │ (None, 64, 64, 128)     │              0 │ add_6[0][0],            │
# │                             │                         │                │ subtract_1[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ up_sampling2d_4             │ (None, 128, 128, 128)   │              0 │ phys_d3[0][0]           │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ concatenate_2 (Concatenate) │ (None, 128, 128, 192)   │              0 │ up_sampling2d_4[0][0],  │
# │                             │                         │                │ add_1[0][0]             │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_36 (Conv2D)          │ (None, 128, 128, 64)    │         12,288 │ concatenate_2[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_37      │ (None, 128, 128, 64)    │            256 │ conv2d_36[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_33 (Activation)  │ (None, 128, 128, 64)    │              0 │ batch_normalization_37… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_15         │ (None, 128, 128, 64)    │            576 │ activation_33[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_38      │ (None, 128, 128, 64)    │            256 │ depthwise_conv2d_15[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_34 (Activation)  │ (None, 128, 128, 64)    │              0 │ batch_normalization_38… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_37 (Conv2D)          │ (None, 128, 128, 64)    │          4,096 │ activation_34[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_39      │ (None, 128, 128, 64)    │            256 │ conv2d_37[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_35 (Activation)  │ (None, 128, 128, 64)    │              0 │ batch_normalization_39… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_16         │ (None, 128, 128, 64)    │            576 │ activation_35[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_40      │ (None, 128, 128, 64)    │            256 │ depthwise_conv2d_16[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_36 (Activation)  │ (None, 128, 128, 64)    │              0 │ batch_normalization_40… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_38 (Conv2D)          │ (None, 128, 128, 64)    │          4,096 │ activation_36[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_41      │ (None, 128, 128, 64)    │            256 │ conv2d_38[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_37 (Activation)  │ (None, 128, 128, 64)    │              0 │ batch_normalization_41… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_7 (ECABlock)      │ (None, 128, 128, 64)    │              3 │ activation_37[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_7           │ (None, 128, 128, 64)    │          1,041 │ eca_block_7[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d_6         │ (None, 128, 128, 64)    │              0 │ pixel_attention_7[0][0] │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_7 (Add)                 │ (None, 128, 128, 64)    │              0 │ spatial_dropout2d_6[0]… │
# │                             │                         │                │ activation_33[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ up_sampling2d_5             │ (None, 256, 256, 64)    │              0 │ add_7[0][0]             │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ concatenate_3 (Concatenate) │ (None, 256, 256, 96)    │              0 │ up_sampling2d_5[0][0],  │
# │                             │                         │                │ add[0][0]               │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_41 (Conv2D)          │ (None, 256, 256, 32)    │          3,072 │ concatenate_3[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_42      │ (None, 256, 256, 32)    │            128 │ conv2d_41[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_38 (Activation)  │ (None, 256, 256, 32)    │              0 │ batch_normalization_42… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_17         │ (None, 256, 256, 32)    │            288 │ activation_38[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_43      │ (None, 256, 256, 32)    │            128 │ depthwise_conv2d_17[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_39 (Activation)  │ (None, 256, 256, 32)    │              0 │ batch_normalization_43… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_42 (Conv2D)          │ (None, 256, 256, 32)    │          1,024 │ activation_39[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_44      │ (None, 256, 256, 32)    │            128 │ conv2d_42[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_40 (Activation)  │ (None, 256, 256, 32)    │              0 │ batch_normalization_44… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_18         │ (None, 256, 256, 32)    │            288 │ activation_40[0][0]     │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_45      │ (None, 256, 256, 32)    │            128 │ depthwise_conv2d_18[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_41 (Activation)  │ (None, 256, 256, 32)    │              0 │ batch_normalization_45… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_43 (Conv2D)          │ (None, 256, 256, 32)    │          1,024 │ activation_41[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_46      │ (None, 256, 256, 32)    │            128 │ conv2d_43[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_42 (Activation)  │ (None, 256, 256, 32)    │              0 │ batch_normalization_46… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ eca_block_8 (ECABlock)      │ (None, 256, 256, 32)    │              3 │ activation_42[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pixel_attention_8           │ (None, 256, 256, 32)    │            265 │ eca_block_8[0][0]       │
# │ (PixelAttention)            │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ spatial_dropout2d_7         │ (None, 256, 256, 32)    │              0 │ pixel_attention_8[0][0] │
# │ (SpatialDropout2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ add_8 (Add)                 │ (None, 256, 256, 32)    │              0 │ spatial_dropout2d_7[0]… │
# │                             │                         │                │ activation_38[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ depthwise_conv2d_19         │ (None, 256, 256, 32)    │            288 │ add_8[0][0]             │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_47      │ (None, 256, 256, 32)    │            128 │ depthwise_conv2d_19[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_43 (Activation)  │ (None, 256, 256, 32)    │              0 │ batch_normalization_47… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2d_46 (Conv2D)          │ (None, 256, 256, 16)    │            512 │ activation_43[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ global_average_pooling2d_5  │ (None, 512)             │              0 │ dropout[0][0]           │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ batch_normalization_48      │ (None, 256, 256, 16)    │             64 │ conv2d_46[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dense (Dense)               │ (None, 64)              │         32,832 │ global_average_pooling… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ activation_44 (Activation)  │ (None, 256, 256, 16)    │              0 │ batch_normalization_48… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dropout_1 (Dropout)         │ (None, 64)              │              0 │ dense[0][0]             │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ raw_conv (Conv2D)           │ (None, 256, 256, 3)     │             48 │ activation_44[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dense_1 (Dense)             │ (None, 32)              │          2,080 │ dropout_1[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ raw_sigmoid (Activation)    │ (None, 256, 256, 3)     │              0 │ raw_conv[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ atm_light (Dense)           │ (None, 3)               │             99 │ dense_1[0][0]           │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ t_full (UpSampling2D)       │ (None, 256, 256, 1)     │              0 │ transmission[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ physics_output              │ (None, 256, 256, 3)     │              0 │ raw_sigmoid[0][0],      │
# │ (PhysicsCorrectionLayer)    │                         │                │ atm_light[0][0],        │
# │                             │                         │                │ t_full[0][0]            │
# └─────────────────────────────┴─────────────────────────┴────────────────┴─────────────────────────┘
#  Total params: 1,481,871 (5.65 MB)
#  Trainable params: 1,466,985 (5.60 MB)
#  Non-trainable params: 14,886 (58.15 KB)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# ══════════════════════════════════════════════════════════════
# CELL 8 — LOSS FUNCTIONS (with VGG Perceptual Loss)
# ══════════════════════════════════════════════════════════════
from tensorflow.keras.applications import VGG16

# --- VGG16 Perceptual Feature Extractor (frozen, adds 0 trainable params) ---
_vgg_base = VGG16(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
_vgg_base.trainable = False
perceptual_model = Model(
    inputs=_vgg_base.input,
    outputs=[_vgg_base.get_layer('block1_conv2').output,
             _vgg_base.get_layer('block2_conv2').output,
             _vgg_base.get_layer('block3_conv3').output],
    name='vgg_perceptual'
)
perceptual_model.trainable = False

# --- Helper ---
def cast_f32(a, b):
    return tf.cast(a, tf.float32), tf.cast(b, tf.float32)

# --- Individual Losses ---
def mae_loss(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    return tf.reduce_mean(tf.abs(y_true - y_pred))

def charbonnier_loss(y_true, y_pred, eps=1e-3):
    y_true, y_pred = cast_f32(y_true, y_pred)
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + eps*eps))

def ssim_loss(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    return 1.0 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

def edge_loss(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    return tf.reduce_mean(tf.abs(tf.image.sobel_edges(y_true) - tf.image.sobel_edges(y_pred)))

def frequency_loss(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    def log_fft(img):
        gray = tf.reduce_mean(img, axis=-1)
        return tf.math.log1p(tf.abs(tf.signal.rfft2d(gray)))
    return tf.reduce_mean(tf.abs(log_fft(y_true) - log_fft(y_pred)))

def perceptual_loss(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    mean = tf.constant([123.68, 116.779, 103.939], shape=[1, 1, 1, 3], dtype=tf.float32)
    true_feats = perceptual_model(y_true * 255.0 - mean, training=False)
    pred_feats = perceptual_model(y_pred * 255.0 - mean, training=False)
    loss = 0.0
    for t_f, p_f in zip(true_feats, pred_feats):
        loss += tf.reduce_mean(tf.abs(t_f - p_f))
    return loss / 3.0

# --- Combined Losses (S1/S2 and S3) ---
def combined_loss(y_true, y_pred):
    return (W_MAE    * charbonnier_loss(y_true, y_pred)
          + W_SSIM   * ssim_loss(y_true, y_pred)
          + W_EDGE   * edge_loss(y_true, y_pred)
          + W_FREQ   * frequency_loss(y_true, y_pred)
          + W_PERCEP * perceptual_loss(y_true, y_pred))

def combined_loss_s3(y_true, y_pred):
    return (0.40 * charbonnier_loss(y_true, y_pred)
          + 0.20 * ssim_loss(y_true, y_pred)
          + 0.10 * edge_loss(y_true, y_pred)
          + 0.05 * frequency_loss(y_true, y_pred)
          + 0.25 * perceptual_loss(y_true, y_pred))

# --- Metrics ---
def psnr_metric(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

def ssim_metric(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

def mae_metric(y_true, y_pred):
    y_true, y_pred = cast_f32(y_true, y_pred)
    return tf.reduce_mean(tf.abs(y_true - y_pred))

print("Loss functions defined (VGG Perceptual active)")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Loss functions defined (VGG Perceptual active)

# %%
# ══════════════════════════════════════════════════════════════
# CELL 9 — LR SCHEDULE & CALLBACKS
# ══════════════════════════════════════════════════════════════
class WarmupCosineDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, peak_lr, warmup_steps, total_steps, min_lr=MIN_LR):
        self.peak_lr = float(peak_lr)
        self.warmup_steps = float(warmup_steps)
        self.total_steps = float(total_steps)
        self.min_lr = float(min_lr)
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warmup_lr = self.peak_lr * (step / (self.warmup_steps + 1e-8))
        progress = (step - self.warmup_steps) / (self.total_steps - self.warmup_steps + 1e-8)
        cos_lr = self.min_lr + 0.5 * (self.peak_lr - self.min_lr) * (
            1.0 + tf.cos(3.14159265 * tf.clip_by_value(progress, 0.0, 1.0)))
        return tf.where(step < self.warmup_steps, warmup_lr, cos_lr)
    def get_config(self):
        return {'peak_lr': self.peak_lr, 'warmup_steps': self.warmup_steps,
                'total_steps': self.total_steps, 'min_lr': self.min_lr}

class CSVMetricsLogger(callbacks.Callback):
    def __init__(self, path, stage):
        super().__init__()
        self.path = path; self.stage = stage; self.records = []
    def on_epoch_end(self, epoch, logs=None):
        row = {'epoch': epoch, 'stage': self.stage}
        row.update(logs or {})
        try:
            opt = self.model.optimizer
            lr = opt.learning_rate
            row['lr'] = float(lr(opt.iterations) if callable(lr) else lr)
        except: row['lr'] = 0.0
        self.records.append(row)
        pd.DataFrame(self.records).to_csv(self.path, index=False)

class SampleVizCallback(callbacks.Callback):
    def __init__(self, val_ds, save_dir, every_n=10):
        super().__init__()
        self.val_ds = val_ds; self.save_dir = save_dir; self.every_n = every_n
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.every_n != 0: return
        for hb, gb in self.val_ds.take(1):
            pb = self.model.predict(hb[:4], verbose=0)
            fig, axes = plt.subplots(4, 3, figsize=(12, 16))
            for i in range(min(4, len(hb))):
                axes[i,0].imshow(np.clip(hb[i].numpy(),0,1)); axes[i,0].set_title('Hazy'); axes[i,0].axis('off')
                axes[i,1].imshow(np.clip(pb[i],0,1)); axes[i,1].set_title('Pred'); axes[i,1].axis('off')
                axes[i,2].imshow(np.clip(gb[i].numpy(),0,1)); axes[i,2].set_title('GT'); axes[i,2].axis('off')
            plt.suptitle(f'Epoch {epoch+1}')
            plt.tight_layout()
            plt.savefig(f'{self.save_dir}/ep{epoch+1:03d}.png', dpi=80, bbox_inches='tight')
            plt.close()

def make_callbacks(stage, lr, warmup_ep, total_ep, steps):
    total_steps = total_ep * steps
    warmup_steps = warmup_ep * steps
    lr_schedule = WarmupCosineDecay(lr, warmup_steps, total_steps)
    cb = [
        callbacks.ModelCheckpoint(
            f'{MODEL_DIR}/stage{stage}_best.keras',
            monitor='val_psnr_metric', mode='max', save_best_only=True, verbose=1),
        callbacks.EarlyStopping(
            monitor='val_psnr_metric', mode='max',
            patience=PATIENCE_ES, restore_best_weights=True, verbose=1),

        CSVMetricsLogger(f'{HISTORY_DIR}/stage{stage}_history.csv', stage),
        SampleVizCallback(val_ds, PLOT_DIR, every_n=10),
    ]
    return lr_schedule, cb

print("LR schedule and callbacks defined")
# Out:
# LR schedule and callbacks defined

# %% [markdown]
# ## Stage 1 — Full Model Training (60 epochs, LR=1e-3)

# %%
# ══════════════════════════════════════════════════════════════
# CELL 10 — STAGE 1 TRAINING
# ══════════════════════════════════════════════════════════════
"""
print("\n" + "="*60)
print("STAGE 1 — Full Model Training")
# print(f"Epochs: {EPOCHS_S+21} | LR: {LR_S1} | Warmup: {WARMUP_S1} ep")
# print("="*60)

lr_s1, cbs_s1 = make_callbacks(1, LR_S1, WARMUP_S1, EPOCHS_S1, STEPS_PER_EPOCH)

optimizer_s1 = tf.keras.optimizers.AdamW(
    learning_rate=lr_s1, weight_decay=1e-4, clipnorm=1.0)

model.load_weights(f'/kaggle/input/datasets/codeninjalucky/stage1-best-weights/stage1_best.keras')

model.compile(optimizer=optimizer_s1, loss=combined_loss,
              metrics=[psnr_metric, ssim_metric, mae_metric])

t0 = time.time()
history1 = model.fit(train_ds, epochs=EPOCHS_S1, validation_data=val_ds,
                     callbacks=cbs_s1, verbose=1,initial_epoch=21)
t1 = time.time()

best_s1 = max(history1.history.get('val_psnr_metric', [0]))
print(f"\nStage 1: {(t1-t0)/3600:.2f}h | Best val PSNR: {best_s1:.4f} dB")
gc.collect()

"""
# Out:
# ============================================================
# STAGE 1 — Full Model Training
# Epoch 22/60
# 2026-05-27 03:28:12.402535: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_9}}
# E0000 00:00:1779852540.255208     370 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/ECA_LDNet_1/spatial_dropout2d_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1779852548.600858     428 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.3678 - mae_metric: 0.0305 - psnr_metric: 28.7890 - ssim_metric: 0.9194
# 2026-05-27 03:56:16.476209: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_4}}
# Epoch 22: val_psnr_metric improved from -inf to 30.16981, saving model to /kaggle/working/models/stage1_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1792s 2s/step - loss: 7.3677 - mae_metric: 0.0305 - psnr_metric: 28.7892 - ssim_metric: 0.9194 - val_loss: 6.4873 - val_mae_metric: 0.0260 - val_psnr_metric: 30.1698 - val_ssim_metric: 0.9519
# Epoch 23/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.2818 - mae_metric: 0.0296 - psnr_metric: 29.0443 - ssim_metric: 0.9197
# Epoch 23: val_psnr_metric did not improve from 30.16981
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1494s 1s/step - loss: 7.2818 - mae_metric: 0.0296 - psnr_metric: 29.0443 - ssim_metric: 0.9197 - val_loss: 6.5313 - val_mae_metric: 0.0275 - val_psnr_metric: 29.7963 - val_ssim_metric: 0.9495
# Epoch 24/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.2761 - mae_metric: 0.0295 - psnr_metric: 29.0402 - ssim_metric: 0.9205
# Epoch 24: val_psnr_metric improved from 30.16981 to 30.34387, saving model to /kaggle/working/models/stage1_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1501s 1s/step - loss: 7.2761 - mae_metric: 0.0295 - psnr_metric: 29.0402 - ssim_metric: 0.9205 - val_loss: 6.5045 - val_mae_metric: 0.0255 - val_psnr_metric: 30.3439 - val_ssim_metric: 0.9499
# Epoch 25/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.3210 - mae_metric: 0.0300 - psnr_metric: 28.9232 - ssim_metric: 0.9202
# Epoch 25: val_psnr_metric did not improve from 30.34387
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1500s 1s/step - loss: 7.3210 - mae_metric: 0.0300 - psnr_metric: 28.9232 - ssim_metric: 0.9202 - val_loss: 6.5506 - val_mae_metric: 0.0317 - val_psnr_metric: 28.8689 - val_ssim_metric: 0.9480
# Epoch 26/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.3607 - mae_metric: 0.0301 - psnr_metric: 28.8654 - ssim_metric: 0.9195
# Epoch 26: val_psnr_metric did not improve from 30.34387
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1507s 1s/step - loss: 7.3607 - mae_metric: 0.0301 - psnr_metric: 28.8653 - ssim_metric: 0.9195 - val_loss: 6.9497 - val_mae_metric: 0.0279 - val_psnr_metric: 29.4687 - val_ssim_metric: 0.9499
# Epoch 27/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.3830 - mae_metric: 0.0304 - psnr_metric: 28.8276 - ssim_metric: 0.9201
# Epoch 27: val_psnr_metric did not improve from 30.34387
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1503s 1s/step - loss: 7.3830 - mae_metric: 0.0304 - psnr_metric: 28.8276 - ssim_metric: 0.9201 - val_loss: 7.6968 - val_mae_metric: 0.0399 - val_psnr_metric: 26.9825 - val_ssim_metric: 0.9277
# Epoch 28/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.3441 - mae_metric: 0.0300 - psnr_metric: 28.9201 - ssim_metric: 0.9198
# Epoch 28: val_psnr_metric did not improve from 30.34387
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1513s 1s/step - loss: 7.3441 - mae_metric: 0.0300 - psnr_metric: 28.9201 - ssim_metric: 0.9198 - val_loss: 6.7934 - val_mae_metric: 0.0277 - val_psnr_metric: 29.5460 - val_ssim_metric: 0.9501
# Epoch 29/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.3041 - mae_metric: 0.0295 - psnr_metric: 29.0402 - ssim_metric: 0.9206
# Epoch 29: val_psnr_metric did not improve from 30.34387
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1507s 1s/step - loss: 7.3041 - mae_metric: 0.0295 - psnr_metric: 29.0402 - ssim_metric: 0.9206 - val_loss: 6.4024 - val_mae_metric: 0.0257 - val_psnr_metric: 30.2755 - val_ssim_metric: 0.9536
# Epoch 30/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.2311 - mae_metric: 0.0289 - psnr_metric: 29.2042 - ssim_metric: 0.9218
# Epoch 30: val_psnr_metric improved from 30.34387 to 30.50596, saving model to /kaggle/working/models/stage1_best.keras
# 2026-05-27 07:18:32.396277: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_4}}
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1508s 1s/step - loss: 7.2312 - mae_metric: 0.0289 - psnr_metric: 29.2042 - ssim_metric: 0.9218 - val_loss: 6.4645 - val_mae_metric: 0.0246 - val_psnr_metric: 30.5060 - val_ssim_metric: 0.9539
# Epoch 31/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.1945 - mae_metric: 0.0287 - psnr_metric: 29.2806 - ssim_metric: 0.9224
# Epoch 31: val_psnr_metric did not improve from 30.50596
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1471s 1s/step - loss: 7.1945 - mae_metric: 0.0287 - psnr_metric: 29.2806 - ssim_metric: 0.9224 - val_loss: 6.8878 - val_mae_metric: 0.0262 - val_psnr_metric: 29.9529 - val_ssim_metric: 0.9517
# Epoch 32/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.1830 - mae_metric: 0.0286 - psnr_metric: 29.2988 - ssim_metric: 0.9227
# Epoch 32: val_psnr_metric did not improve from 30.50596
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1411s 1s/step - loss: 7.1830 - mae_metric: 0.0286 - psnr_metric: 29.2988 - ssim_metric: 0.9227 - val_loss: 6.6012 - val_mae_metric: 0.0275 - val_psnr_metric: 29.8019 - val_ssim_metric: 0.9528
# Epoch 33/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.1438 - mae_metric: 0.0282 - psnr_metric: 29.4052 - ssim_metric: 0.9231
# Epoch 33: val_psnr_metric did not improve from 30.50596
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1408s 1s/step - loss: 7.1438 - mae_metric: 0.0282 - psnr_metric: 29.4052 - ssim_metric: 0.9231 - val_loss: 6.4924 - val_mae_metric: 0.0256 - val_psnr_metric: 30.4052 - val_ssim_metric: 0.9496
# Epoch 34/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.0785 - mae_metric: 0.0275 - psnr_metric: 29.5929 - ssim_metric: 0.9238
# Epoch 34: val_psnr_metric did not improve from 30.50596
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1409s 1s/step - loss: 7.0785 - mae_metric: 0.0275 - psnr_metric: 29.5929 - ssim_metric: 0.9238 - val_loss: 6.3654 - val_mae_metric: 0.0260 - val_psnr_metric: 30.2477 - val_ssim_metric: 0.9556
# Epoch 35/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.0591 - mae_metric: 0.0272 - psnr_metric: 29.6763 - ssim_metric: 0.9240
# Epoch 35: val_psnr_metric improved from 30.50596 to 30.86997, saving model to /kaggle/working/models/stage1_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1415s 1s/step - loss: 7.0591 - mae_metric: 0.0272 - psnr_metric: 29.6763 - ssim_metric: 0.9240 - val_loss: 6.2354 - val_mae_metric: 0.0239 - val_psnr_metric: 30.8700 - val_ssim_metric: 0.9534
# Epoch 36/60
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.9800 - mae_metric: 0.0269 - psnr_metric: 29.7867 - ssim_metric: 0.9252
# Epoch 36: val_psnr_metric improved from 30.86997 to 31.22743, saving model to /kaggle/working/models/stage1_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1415s 1s/step - loss: 6.9800 - mae_metric: 0.0269 - psnr_metric: 29.7867 - ssim_metric: 0.9252 - val_loss: 6.1631 - val_mae_metric: 0.0227 - val_psnr_metric: 31.2274 - val_ssim_metric: 0.9534
# Epoch 37/60
#  249/1125 ━━━━━━━━━━━━━━━━━━━━ 17:58 1s/step - loss: 6.9826 - mae_metric: 0.0267 - psnr_metric: 29.8319 - ssim_metric: 0.9256

# %% [markdown]
# ## Stage 2 — Fine-tuning (30 epochs, LR=1e-4)

# %%
# ══════════════════════════════════════════════════════════════
# CELL 11 — STAGE 2 TRAINING
# ══════════════════════════════════════════════════════════════
print("\n" + "="*60)
print("STAGE 2 — Fine-tuning")
print(f"Epochs: {EPOCHS_S2} | LR: {LR_S2} | Warmup: {WARMUP_S2} ep")
print("="*60)

model.load_weights(f'/kaggle/input/models/codeninjalucky/model-stage1-complete-/tensorflow2/default/1/stage1_best.keras')
print("Stage 1 best weights loaded")

lr_s2, cbs_s2 = make_callbacks(2, LR_S2, WARMUP_S2, EPOCHS_S2, STEPS_PER_EPOCH)

optimizer_s2 = tf.keras.optimizers.AdamW(
    learning_rate=lr_s2, weight_decay=5e-5, clipnorm=1.0)

model.compile(optimizer=optimizer_s2, loss=combined_loss,
              metrics=[psnr_metric, ssim_metric, mae_metric])

t0 = time.time()
history2 = model.fit(train_ds, epochs=EPOCHS_S2, validation_data=val_ds,
                     callbacks=cbs_s2, verbose=1)
t1 = time.time()

best_s2 = max(history2.history.get('val_psnr_metric', [0]))
print(f"\nStage 2: {(t1-t0)/3600:.2f}h | Best val PSNR: {best_s2:.4f} dB")
gc.collect()
# Out:
# ============================================================
# STAGE 2 — Fine-tuning
# Epochs: 30 | LR: 0.0001 | Warmup: 2 ep
# ============================================================
# Stage 1 best weights loaded
# Epoch 1/30
# 2026-05-31 03:24:26.220726: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_9}}
# E0000 00:00:1780197906.431534      57 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/ECA_LDNet_1/spatial_dropout2d_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1780197912.737028     127 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.7519 - mae_metric: 0.0248 - psnr_metric: 30.4375 - ssim_metric: 0.9277
# 2026-05-31 03:51:33.831120: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_4}}
# Epoch 1: val_psnr_metric improved from -inf to 31.48187, saving model to /kaggle/working/models/stage2_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1723s 1s/step - loss: 6.7519 - mae_metric: 0.0248 - psnr_metric: 30.4376 - ssim_metric: 0.9277 - val_loss: 5.9736 - val_mae_metric: 0.0225 - val_psnr_metric: 31.4819 - val_ssim_metric: 0.9558
# Epoch 2/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.7483 - mae_metric: 0.0246 - psnr_metric: 30.4811 - ssim_metric: 0.9272
# Epoch 2: val_psnr_metric improved from 31.48187 to 31.51477, saving model to /kaggle/working/models/stage2_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1417s 1s/step - loss: 6.7483 - mae_metric: 0.0246 - psnr_metric: 30.4812 - ssim_metric: 0.9272 - val_loss: 6.0074 - val_mae_metric: 0.0224 - val_psnr_metric: 31.5148 - val_ssim_metric: 0.9540
# Epoch 3/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.6996 - mae_metric: 0.0242 - psnr_metric: 30.5942 - ssim_metric: 0.9286
# Epoch 3: val_psnr_metric improved from 31.51477 to 31.62549, saving model to /kaggle/working/models/stage2_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1410s 1s/step - loss: 6.6996 - mae_metric: 0.0242 - psnr_metric: 30.5942 - ssim_metric: 0.9286 - val_loss: 5.9584 - val_mae_metric: 0.0221 - val_psnr_metric: 31.6255 - val_ssim_metric: 0.9564
# Epoch 4/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.6795 - mae_metric: 0.0241 - psnr_metric: 30.6298 - ssim_metric: 0.9286
# Epoch 4: val_psnr_metric did not improve from 31.62549
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1430s 1s/step - loss: 6.6795 - mae_metric: 0.0241 - psnr_metric: 30.6298 - ssim_metric: 0.9286 - val_loss: 5.9671 - val_mae_metric: 0.0225 - val_psnr_metric: 31.4669 - val_ssim_metric: 0.9544
# Epoch 5/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.6473 - mae_metric: 0.0236 - psnr_metric: 30.7848 - ssim_metric: 0.9290
# Epoch 5: val_psnr_metric improved from 31.62549 to 31.80889, saving model to /kaggle/working/models/stage2_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1417s 1s/step - loss: 6.6473 - mae_metric: 0.0236 - psnr_metric: 30.7848 - ssim_metric: 0.9290 - val_loss: 5.9327 - val_mae_metric: 0.0215 - val_psnr_metric: 31.8089 - val_ssim_metric: 0.9567
# Epoch 6/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.6445 - mae_metric: 0.0237 - psnr_metric: 30.7781 - ssim_metric: 0.9293
# Epoch 6: val_psnr_metric did not improve from 31.80889
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1414s 1s/step - loss: 6.6445 - mae_metric: 0.0237 - psnr_metric: 30.7781 - ssim_metric: 0.9293 - val_loss: 5.9846 - val_mae_metric: 0.0223 - val_psnr_metric: 31.5246 - val_ssim_metric: 0.9563
# Epoch 7/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.6307 - mae_metric: 0.0234 - psnr_metric: 30.8351 - ssim_metric: 0.9289
# Epoch 7: val_psnr_metric did not improve from 31.80889
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1404s 1s/step - loss: 6.6308 - mae_metric: 0.0234 - psnr_metric: 30.8351 - ssim_metric: 0.9289 - val_loss: 5.9763 - val_mae_metric: 0.0221 - val_psnr_metric: 31.6814 - val_ssim_metric: 0.9558
# Epoch 8/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.6263 - mae_metric: 0.0233 - psnr_metric: 30.8803 - ssim_metric: 0.9292
# Epoch 8: val_psnr_metric did not improve from 31.80889
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1408s 1s/step - loss: 6.6263 - mae_metric: 0.0233 - psnr_metric: 30.8803 - ssim_metric: 0.9292 - val_loss: 5.9492 - val_mae_metric: 0.0220 - val_psnr_metric: 31.6728 - val_ssim_metric: 0.9540
# Epoch 9/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5939 - mae_metric: 0.0232 - psnr_metric: 30.9310 - ssim_metric: 0.9299
# Epoch 9: val_psnr_metric improved from 31.80889 to 31.88590, saving model to /kaggle/working/models/stage2_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1438s 1s/step - loss: 6.5940 - mae_metric: 0.0232 - psnr_metric: 30.9310 - ssim_metric: 0.9299 - val_loss: 5.8912 - val_mae_metric: 0.0214 - val_psnr_metric: 31.8859 - val_ssim_metric: 0.9579
# Epoch 10/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5745 - mae_metric: 0.0230 - psnr_metric: 30.9937 - ssim_metric: 0.9300
# Epoch 10: val_psnr_metric did not improve from 31.88590
# 2026-05-31 07:26:01.013836: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_4}}
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1437s 1s/step - loss: 6.5746 - mae_metric: 0.0230 - psnr_metric: 30.9937 - ssim_metric: 0.9300 - val_loss: 5.9243 - val_mae_metric: 0.0217 - val_psnr_metric: 31.7482 - val_ssim_metric: 0.9584
# Epoch 11/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5937 - mae_metric: 0.0232 - psnr_metric: 30.9342 - ssim_metric: 0.9296
# Epoch 11: val_psnr_metric improved from 31.88590 to 32.03759, saving model to /kaggle/working/models/stage2_best.keras
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1446s 1s/step - loss: 6.5937 - mae_metric: 0.0232 - psnr_metric: 30.9342 - ssim_metric: 0.9296 - val_loss: 5.8652 - val_mae_metric: 0.0210 - val_psnr_metric: 32.0376 - val_ssim_metric: 0.9582
# Epoch 12/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5682 - mae_metric: 0.0229 - psnr_metric: 31.0246 - ssim_metric: 0.9301
# Epoch 12: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1430s 1s/step - loss: 6.5682 - mae_metric: 0.0229 - psnr_metric: 31.0245 - ssim_metric: 0.9301 - val_loss: 5.9760 - val_mae_metric: 0.0223 - val_psnr_metric: 31.5704 - val_ssim_metric: 0.9557
# Epoch 13/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5467 - mae_metric: 0.0227 - psnr_metric: 31.0897 - ssim_metric: 0.9304
# Epoch 13: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1416s 1s/step - loss: 6.5468 - mae_metric: 0.0227 - psnr_metric: 31.0897 - ssim_metric: 0.9304 - val_loss: 6.0033 - val_mae_metric: 0.0222 - val_psnr_metric: 31.6232 - val_ssim_metric: 0.9561
# Epoch 14/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5508 - mae_metric: 0.0224 - psnr_metric: 31.1578 - ssim_metric: 0.9303
# Epoch 14: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1420s 1s/step - loss: 6.5508 - mae_metric: 0.0224 - psnr_metric: 31.1578 - ssim_metric: 0.9303 - val_loss: 5.9310 - val_mae_metric: 0.0219 - val_psnr_metric: 31.7191 - val_ssim_metric: 0.9546
# Epoch 15/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.4902 - mae_metric: 0.0222 - psnr_metric: 31.2518 - ssim_metric: 0.9308
# Epoch 15: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1418s 1s/step - loss: 6.4902 - mae_metric: 0.0222 - psnr_metric: 31.2518 - ssim_metric: 0.9308 - val_loss: 5.9444 - val_mae_metric: 0.0221 - val_psnr_metric: 31.6576 - val_ssim_metric: 0.9558
# Epoch 16/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5887 - mae_metric: 0.0232 - psnr_metric: 30.9418 - ssim_metric: 0.9301
# Epoch 16: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1436s 1s/step - loss: 6.5887 - mae_metric: 0.0232 - psnr_metric: 30.9418 - ssim_metric: 0.9301 - val_loss: 5.9376 - val_mae_metric: 0.0221 - val_psnr_metric: 31.6844 - val_ssim_metric: 0.9563
# Epoch 17/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5754 - mae_metric: 0.0230 - psnr_metric: 30.9960 - ssim_metric: 0.9299
# Epoch 17: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1423s 1s/step - loss: 6.5754 - mae_metric: 0.0230 - psnr_metric: 30.9960 - ssim_metric: 0.9299 - val_loss: 5.8972 - val_mae_metric: 0.0212 - val_psnr_metric: 31.9746 - val_ssim_metric: 0.9569
# Epoch 18/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5778 - mae_metric: 0.0228 - psnr_metric: 31.0385 - ssim_metric: 0.9306
# Epoch 18: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1424s 1s/step - loss: 6.5778 - mae_metric: 0.0228 - psnr_metric: 31.0385 - ssim_metric: 0.9306 - val_loss: 5.8954 - val_mae_metric: 0.0214 - val_psnr_metric: 31.8962 - val_ssim_metric: 0.9558
# Epoch 19/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5626 - mae_metric: 0.0229 - psnr_metric: 31.0344 - ssim_metric: 0.9303
# Epoch 19: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1436s 1s/step - loss: 6.5626 - mae_metric: 0.0229 - psnr_metric: 31.0344 - ssim_metric: 0.9303 - val_loss: 5.9130 - val_mae_metric: 0.0216 - val_psnr_metric: 31.8266 - val_ssim_metric: 0.9569
# Epoch 20/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5629 - mae_metric: 0.0227 - psnr_metric: 31.0781 - ssim_metric: 0.9304
# Epoch 20: val_psnr_metric did not improve from 32.03759
# 2026-05-31 11:24:04.835198: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_4}}
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1432s 1s/step - loss: 6.5629 - mae_metric: 0.0227 - psnr_metric: 31.0781 - ssim_metric: 0.9304 - val_loss: 5.9037 - val_mae_metric: 0.0214 - val_psnr_metric: 31.9032 - val_ssim_metric: 0.9577
# Epoch 21/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5856 - mae_metric: 0.0230 - psnr_metric: 31.0072 - ssim_metric: 0.9302
# Epoch 21: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1428s 1s/step - loss: 6.5856 - mae_metric: 0.0230 - psnr_metric: 31.0071 - ssim_metric: 0.9302 - val_loss: 5.9346 - val_mae_metric: 0.0216 - val_psnr_metric: 31.8416 - val_ssim_metric: 0.9559
# Epoch 22/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5592 - mae_metric: 0.0228 - psnr_metric: 31.0551 - ssim_metric: 0.9308
# Epoch 22: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1442s 1s/step - loss: 6.5592 - mae_metric: 0.0228 - psnr_metric: 31.0551 - ssim_metric: 0.9308 - val_loss: 5.8903 - val_mae_metric: 0.0214 - val_psnr_metric: 31.9057 - val_ssim_metric: 0.9564
# Epoch 23/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5412 - mae_metric: 0.0227 - psnr_metric: 31.0895 - ssim_metric: 0.9307
# Epoch 23: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1422s 1s/step - loss: 6.5413 - mae_metric: 0.0227 - psnr_metric: 31.0895 - ssim_metric: 0.9307 - val_loss: 5.8684 - val_mae_metric: 0.0212 - val_psnr_metric: 31.9875 - val_ssim_metric: 0.9574
# Epoch 24/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5513 - mae_metric: 0.0226 - psnr_metric: 31.1097 - ssim_metric: 0.9308
# Epoch 24: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1403s 1s/step - loss: 6.5513 - mae_metric: 0.0226 - psnr_metric: 31.1097 - ssim_metric: 0.9308 - val_loss: 5.8963 - val_mae_metric: 0.0214 - val_psnr_metric: 31.9074 - val_ssim_metric: 0.9571
# Epoch 25/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5587 - mae_metric: 0.0228 - psnr_metric: 31.0580 - ssim_metric: 0.9302
# Epoch 25: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1418s 1s/step - loss: 6.5587 - mae_metric: 0.0228 - psnr_metric: 31.0580 - ssim_metric: 0.9302 - val_loss: 5.8971 - val_mae_metric: 0.0215 - val_psnr_metric: 31.8777 - val_ssim_metric: 0.9570
# Epoch 26/30
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.5552 - mae_metric: 0.0227 - psnr_metric: 31.0751 - ssim_metric: 0.9300
# Epoch 26: val_psnr_metric did not improve from 32.03759
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 1431s 1s/step - loss: 6.5552 - mae_metric: 0.0227 - psnr_metric: 31.0750 - ssim_metric: 0.9300 - val_loss: 5.9039 - val_mae_metric: 0.0217 - val_psnr_metric: 31.8120 - val_ssim_metric: 0.9560
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# Stage 2: 10.37h | Best val PSNR: 32.0376 dB
# 51279

# %% [markdown]
# ## Stage 3 — Final Polish (20 epochs, LR=5e-5, batch=8)

# %%
def psnr_focused_loss(y_true, y_pred):
    eps = 1e-6
    charb = tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + eps))
    l1 = tf.reduce_mean(tf.abs(y_true - y_pred))
    ssim_loss = 1.0 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))
    ms_ssim_loss = 1.0 - tf.reduce_mean(tf.image.ssim_multiscale(y_true, y_pred, max_val=1.0))
    lap = tf.constant([[0.,1.,0.],[1.,-4.,1.],[0.,1.,0.]], dtype=tf.float32)
    lap = tf.reshape(lap, [3,3,1,1])
    lap = tf.tile(lap, [1,1,3,1])
    edge_loss = tf.reduce_mean(tf.abs(
        tf.nn.depthwise_conv2d(y_true, lap, [1,1,1,1], 'SAME') -
        tf.nn.depthwise_conv2d(y_pred, lap, [1,1,1,1], 'SAME')))
    return 0.35*charb + 0.20*l1 + 0.20*ssim_loss + 0.15*ms_ssim_loss + 0.10*edge_loss







# ══════════════════════════════════════════════════════════════
# CELL 12 — STAGE 3 TRAINING
# ══════════════════════════════════════════════════════════════
# print("\n" + "="*60)
# print("STAGE 3 — Final Polish")
# print(f"Epochs: {EPOCHS_S3} | LR: {LR_S3} | Batch: {BATCH_SIZE_S3}")
# print("="*60)

# model.load_weights(f'{MODEL_DIR}/stage2_best.keras')
# print("Stage 2 best weights loaded")

# STEPS_S3 = len(tr_h) // BATCH_SIZE_S3
# train_ds3 = build_dataset(tr_h, tr_g, augment=True, batch=BATCH_SIZE_S3)
# val_ds3 = build_dataset(va_h, va_g, augment=False, batch=BATCH_SIZE_S3, shuffle=False, cache_ds=True)

# lr_s3, cbs_s3 = make_callbacks(3, LR_S3, 0, EPOCHS_S3, STEPS_S3)

# optimizer_s3 = tf.keras.optimizers.AdamW(
#     learning_rate=lr_s3, weight_decay=2.5e-5, clipnorm=0.5)

# model.compile(optimizer=optimizer_s3, loss=combined_loss_s3,
#               metrics=[psnr_metric, ssim_metric, mae_metric])

# t0 = time.time()
# history3 = model.fit(train_ds3, epochs=EPOCHS_S3, validation_data=val_ds3,
#                      callbacks=cbs_s3, verbose=1)
# t1 = time.time()

# best_s3 = max(history3.history.get('val_psnr_metric', [0]))
# print(f"\nStage 3: {(t1-t0)/3600:.2f}h | Best val PSNR: {best_s3:.4f} dB")

# # Load absolute best
# best_stage = int(np.argmax([best_s1, best_s2, best_s3])) + 1
# model.load_weights(f'{MODEL_DIR}/stage{best_stage}_best.keras')
# print(f"Loaded best from Stage {best_stage} (PSNR={max(best_s1,best_s2,best_s3):.4f})")
# gc.collect()




LR_S3 = 5e-5
EPOCHS_S3 = 40  # more room — new loss needs time to push PSNR up

lr_s3, cbs_s3 = make_callbacks(3, LR_S3, 0, EPOCHS_S3, STEPS_PER_EPOCH)


optimizer_s3 = tf.keras.optimizers.AdamW(
    learning_rate=lr_s3, weight_decay=5e-5, clipnorm=0.5)

model.load_weights('/kaggle/working/models/stage2_best.keras')

model.compile(optimizer=optimizer_s3, loss=psnr_focused_loss,
              metrics=[psnr_metric, ssim_metric, mae_metric])

history3 = model.fit(train_ds, epochs=EPOCHS_S3,
                     validation_data=val_ds, callbacks=cbs_s3)

# %% [markdown]
# ## Save All Artifacts

# %%
model.save(f'{MODEL_DIR}/stage3_final.keras')
model.save_weights(f'{MODEL_DIR}/weights_final.h5')
print("Models saved")

def h2df(hist, stage):
    df = pd.DataFrame(hist.history)
    df['stage'] = stage
    df['epoch'] = range(len(df))
    return df

df1, df2, df3 = h2df(history1,1), h2df(history2,2), h2df(history3,3)
df_all = pd.concat([df1, df2, df3], ignore_index=True)
df_all.to_csv(f'{HISTORY_DIR}/full_history.csv', index=False)
print("History saved")

# Training curves
fig, axes = plt.subplots(2, 2, figsize=(18, 12))
colors = {'1':('#2196F3','#1565C0'), '2':('#4CAF50','#1B5E20'), '3':('#FF9800','#E65100')}
for df, s in [(df1,'1'),(df2,'2'),(df3,'3')]:
    c1, c2 = colors[s]
    ep = df['epoch'].values
    if 'loss' in df.columns:
        axes[0,0].plot(ep, df['loss'], color=c1, label=f'Train S{s}')
        axes[0,0].plot(ep, df['val_loss'], color=c2, ls='--', label=f'Val S{s}')
    if 'psnr_metric' in df.columns:
        axes[0,1].plot(ep, df['psnr_metric'], color=c1, label=f'Train S{s}')
        axes[0,1].plot(ep, df['val_psnr_metric'], color=c2, ls='--', label=f'Val S{s}')
    if 'ssim_metric' in df.columns:
        axes[1,0].plot(ep, df['ssim_metric'], color=c1, label=f'Train S{s}')
        axes[1,0].plot(ep, df['val_ssim_metric'], color=c2, ls='--', label=f'Val S{s}')
    if 'mae_metric' in df.columns:
        axes[1,1].plot(ep, df['mae_metric'], color=c1, label=f'Train S{s}')
        axes[1,1].plot(ep, df['val_mae_metric'], color=c2, ls='--', label=f'Val S{s}')
for ax, t in zip(axes.flat, ['Loss','PSNR (dB)','SSIM','MAE']):
    ax.set_title(t, fontsize=13, fontweight='bold')
    ax.legend(fontsize=7, ncol=2); ax.grid(alpha=0.3)
plt.suptitle('ECA-LDNet Training History', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig(f'{PLOT_DIR}/training_curves.png', dpi=150, bbox_inches='tight')
plt.show()
print("Plots saved")

# %% [markdown]
# ## Inference Utilities

# %%
def gaussian_window_2d(size, sigma=0.35):
    c = np.linspace(-1, 1, size)
    g = np.exp(-(c**2) / (2*sigma**2))
    w = np.outer(g, g)
    return (w / w.max()).astype(np.float32)

def sliding_window_predict(model, img, patch=IMG_SIZE, stride=64, batch_size=8):
    H, W = img.shape[:2]
    output = np.zeros((H,W,3), np.float32)
    weight = np.zeros((H,W,3), np.float32)
    win3d = gaussian_window_2d(patch)[:,:,np.newaxis]
    ys = list(range(0, max(H-patch,1), stride))
    xs = list(range(0, max(W-patch,1), stride))
    if not ys or ys[-1] != max(H-patch,0): ys.append(max(H-patch,0))
    if not xs or xs[-1] != max(W-patch,0): xs.append(max(W-patch,0))
    coords = [(y,x) for y in ys for x in xs]
    crops = np.stack([img[y:y+patch, x:x+patch] for y,x in coords]).astype(np.float32)
    preds = model.predict(crops, batch_size=batch_size, verbose=0)
    for pred_p, (y,x) in zip(preds, coords):
        output[y:y+patch, x:x+patch] += pred_p * win3d
        weight[y:y+patch, x:x+patch] += win3d
    return np.clip(output / (weight + 1e-8), 0, 1)

def predict_full(model, img, patch=IMG_SIZE, stride=64, batch_size=8, tta=True):
    H, W = img.shape[:2]
    def _pred(im):
        if H <= patch and W <= patch:
            return model.predict(im[np.newaxis], verbose=0)[0].astype(np.float32)
        return sliding_window_predict(model, im, patch, stride, batch_size)
    out = _pred(img)
    if tta:
        o_lr = _pred(img[:,::-1,:])[:,::-1,:]
        o_ud = _pred(img[::-1,:,:])[::-1,:,:]
        o_r  = np.rot90(_pred(np.rot90(img,1)), -1)
        out  = (out + o_lr + o_ud + o_r) / 4.0
    return np.clip(out, 0, 1).astype(np.float32)

print("Inference utilities defined")

# %% [markdown]
# ## Full Evaluation on All Test Sets

# %%
def evaluate_dataset(model, hazy_dir, gt_dir, name, limit=None, tta=True, save_csv=None):
    if not hazy_dir or not gt_dir:
        print(f"  SKIP {name} — not found")
        return None
    files = sorted([f for f in os.listdir(hazy_dir) if f.lower().endswith(('.png','.jpg','.jpeg','.bmp'))])
    if limit: files = files[:limit]
    print(f"\nEvaluating [{name}] — {len(files)} images, TTA={tta}")
    records = []
    for i, fname in enumerate(files):
        hp = os.path.join(hazy_dir, fname)
        gp = get_gt_path(fname, gt_dir)
        if not gp: continue
        hazy, gt = load_image_pair(hp, gp)
        if hazy is None: continue
        pred = predict_full(model, hazy, tta=tta)
        p = float(tf.image.psnr(pred[np.newaxis], gt[np.newaxis], max_val=1.0))
        s = float(tf.image.ssim(pred[np.newaxis], gt[np.newaxis], max_val=1.0))
        m = float(np.mean(np.abs(pred - gt)))
        records.append({'file': fname, 'PSNR': p, 'SSIM': s, 'MAE': m})
        if (i+1) % 100 == 0:
            print(f"  [{i+1}/{len(files)}] PSNR: {np.mean([r['PSNR'] for r in records]):.4f}")
    df = pd.DataFrame(records)
    if len(df) > 0:
        print(f"  {name}: PSNR={df.PSNR.mean():.4f}+-{df.PSNR.std():.4f}  SSIM={df.SSIM.mean():.4f}")
    if save_csv: df.to_csv(save_csv, index=False)
    return df

all_results = {}
df_r6k = evaluate_dataset(model, R6K_TEST_HAZY, R6K_TEST_GT, 'RESIDE-6K', 1000, True,
                           f'{METRIC_DIR}/results_reside6k.csv')
if df_r6k is not None: all_results['RESIDE-6K'] = df_r6k

df_si = evaluate_dataset(model, SOTS_IN_HAZY, SOTS_IN_GT, 'SOTS Indoor', 500, True,
                          f'{METRIC_DIR}/results_sots_indoor.csv')
if df_si is not None: all_results['SOTS Indoor'] = df_si

df_so = evaluate_dataset(model, SOTS_OUT_HAZY, SOTS_OUT_GT, 'SOTS Outdoor', 500, True,
                          f'{METRIC_DIR}/results_sots_outdoor.csv')
if df_so is not None: all_results['SOTS Outdoor'] = df_so

# %% [markdown]
# ## Visual Comparison Plots

# %%
def plot_comparison(model, hazy_dir, gt_dir, save_path, title='Results', tta=False):
    if not hazy_dir or not gt_dir: return
    files = sorted(os.listdir(hazy_dir))
    random.shuffle(files)
    samples = []
    for fname in files[:100]:
        if not fname.lower().endswith(('.png','.jpg','.jpeg','.bmp')): continue
        gp = get_gt_path(fname, gt_dir)
        if not gp: continue
        hazy, gt = load_image_pair(os.path.join(hazy_dir, fname), gp)
        if hazy is None: continue
        pred = predict_full(model, hazy, tta=tta)
        pv = float(tf.image.psnr(pred[np.newaxis], gt[np.newaxis], max_val=1.0))
        sv = float(tf.image.ssim(pred[np.newaxis], gt[np.newaxis], max_val=1.0))
        samples.append((pv, sv, hazy, pred, gt))
        if len(samples) >= 30: break
    if len(samples) < 6:
        print(f"Not enough samples for {title}")
        return
    samples.sort(key=lambda x: x[0])
    show = samples[:3] + samples[-3:]
    labels = ['Worst']*3 + ['Best']*3
    fig, axes = plt.subplots(6, 4, figsize=(20, 28))
    for row, (pv, sv, hazy, pred, gt) in enumerate(show):
        error = np.abs(pred - gt)
        axes[row,0].imshow(np.clip(hazy,0,1)); axes[row,0].set_title(f'[{labels[row]}] Hazy'); axes[row,0].axis('off')
        axes[row,1].imshow(np.clip(pred,0,1)); axes[row,1].set_title(f'Pred PSNR={pv:.2f}'); axes[row,1].axis('off')
        axes[row,2].imshow(np.clip(gt,0,1)); axes[row,2].set_title('GT'); axes[row,2].axis('off')
        im = axes[row,3].imshow(error, cmap='hot', vmin=0, vmax=0.3); axes[row,3].set_title('Error'); axes[row,3].axis('off')
        plt.colorbar(im, ax=axes[row,3], fraction=0.046, pad=0.04)
    plt.suptitle(title, fontsize=16, fontweight='bold')
    plt.tight_layout(); plt.savefig(save_path, dpi=120, bbox_inches='tight'); plt.show()

plot_comparison(model, R6K_TEST_HAZY, R6K_TEST_GT, f'{RESULT_DIR}/visual_reside6k.png',
                'ECA-LDNet — RESIDE-6K Results')
plot_comparison(model, SOTS_IN_HAZY, SOTS_IN_GT, f'{RESULT_DIR}/visual_sots_indoor.png',
                'ECA-LDNet — SOTS Indoor Results')
plot_comparison(model, SOTS_OUT_HAZY, SOTS_OUT_GT, f'{RESULT_DIR}/visual_sots_outdoor.png',
                'ECA-LDNet — SOTS Outdoor Results')

# %% [markdown]
# ## Pixel Distribution & Quality Analysis

# %%
def plot_pixel_distribution(model, hazy_dir, gt_dir, save_path, n_samples=50):
    if not hazy_dir or not gt_dir: return
    files = sorted(os.listdir(hazy_dir))[:n_samples]
    hazy_all, pred_all, gt_all = [], [], []
    for fname in files:
        if not fname.lower().endswith(('.png','.jpg','.jpeg','.bmp')): continue
        gp = get_gt_path(fname, gt_dir)
        if not gp: continue
        hazy, gt = load_image_pair(os.path.join(hazy_dir, fname), gp)
        if hazy is None: continue
        pred = predict_full(model, hazy, tta=False)
        hazy_all.append(hazy); pred_all.append(pred); gt_all.append(gt)
    if len(hazy_all) == 0: return
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
    ax1.hist(np.concatenate([h.flatten() for h in hazy_all]), bins=60, alpha=0.5, label='Hazy', color='orange')
    ax1.hist(np.concatenate([p.flatten() for p in pred_all]), bins=60, alpha=0.5, label='Predicted', color='blue')
    ax1.hist(np.concatenate([g.flatten() for g in gt_all]), bins=60, alpha=0.5, label='GT', color='green')
    ax1.set_title('Pixel Distribution'); ax1.legend(); ax1.grid(alpha=0.3)
    def sharp(imgs):
        scores = []
        for im in imgs[:10]:
            gray = cv2.cvtColor((im*255).astype(np.uint8), cv2.COLOR_RGB2GRAY)
            scores.append(cv2.Laplacian(gray, cv2.CV_64F).var())
        return np.mean(scores)
    vals = [sharp(hazy_all), sharp(pred_all), sharp(gt_all)]
    bars = ax2.bar(['Hazy','Predicted','GT'], vals, color=['orange','blue','green'], alpha=0.8)
    ax2.bar_label(bars, fmt='%.1f'); ax2.set_title('Sharpness'); ax2.grid(axis='y', alpha=0.3)
    plt.tight_layout(); plt.savefig(save_path, dpi=120, bbox_inches='tight'); plt.show()

plot_pixel_distribution(model, R6K_TEST_HAZY, R6K_TEST_GT, f'{RESULT_DIR}/pixel_analysis.png')

# %% [markdown]
# ## Final Report & Paper Tables

# %%
# Inference speed
dummy = np.random.rand(1, IMG_SIZE, IMG_SIZE, 3).astype(np.float32)
_ = model.predict(dummy, verbose=0)
timings = []
for _ in range(30):
    t0 = time.time(); model.predict(dummy, verbose=0); timings.append(time.time()-t0)
avg_ms = np.mean(timings)*1000
fps = 1000/avg_ms

# Get best results
def get_mean(name, col):
    if name in all_results and len(all_results[name]) > 0:
        return all_results[name][col].mean()
    return 0.0

my_psnr = get_mean('SOTS Indoor','PSNR') or get_mean('RESIDE-6K','PSNR')
my_ssim = get_mean('SOTS Indoor','SSIM') or get_mean('RESIDE-6K','SSIM')

comparison = pd.DataFrame({
    'Method': ['DCP','DehazeNet','MSCNN','AOD-Net','GFN','GridDehazeNet','FFA-Net','ECA-LDNet (Ours)'],
    'Year': [2009,2016,2016,2017,2018,2019,2020,2025],
    'PSNR': [16.62,21.14,17.57,19.06,21.55,32.16,36.39,round(my_psnr,2)],
    'SSIM': [0.818,0.847,0.810,0.850,0.844,0.984,0.989,round(my_ssim,4)],
    'Params': ['—','0.009M','0.008M','0.002M','0.530M','0.956M','4.456M',f'{model.count_params()/1e6:.3f}M'],
})
comparison.to_csv(f'{METRIC_DIR}/comparison_table.csv', index=False)

with open(f'{METRIC_DIR}/final_report.txt', 'w') as f:
    f.write("ECA-LDNet — Final Report\n" + "="*60 + "\n")
    f.write(f"Parameters: {model.count_params():,} ({model.count_params()/1e6:.3f}M)\n")
    f.write(f"Inference: {avg_ms:.1f} ms ({fps:.1f} FPS)\n\n")
    for name, df in all_results.items():
        f.write(f"{name} ({len(df)} imgs): PSNR={df.PSNR.mean():.4f} SSIM={df.SSIM.mean():.4f}\n")
    f.write("\n" + comparison.to_string(index=False))

print("\n" + "="*65)
print("FINAL SUMMARY — ECA-LDNet")
print("="*65)
print(f"  Params: {model.count_params():,} ({model.count_params()/1e6:.3f}M)")
print(f"  Speed:  {avg_ms:.1f} ms ({fps:.1f} FPS)")
for name, df in all_results.items():
    print(f"  {name:<15}: PSNR={df.PSNR.mean():.4f} SSIM={df.SSIM.mean():.4f}")
print("\nComparison:")
print(comparison.to_string(index=False))
print("="*65)
print("TRAINING COMPLETE")

# %% [markdown]
# ## Offline Testing Script (Copy to local machine)

# %%
offline_script = '''
#!/usr/bin/env python3
"""ECA-LDNet Offline Testing — run on local machine after downloading model"""
import os, cv2, sys, numpy as np, argparse
import tensorflow as tf

IMG_SIZE = 256

# Register custom objects
class ECABlock(tf.keras.layers.Layer):
    def __init__(self, kernel_size=3, **kw):
        super().__init__(**kw); self.kernel_size = kernel_size
    def build(self, input_shape):
        self.channels = input_shape[-1]
        self.conv = tf.keras.layers.Conv1D(1, self.kernel_size, padding="same", use_bias=False)
        self.gap = tf.keras.layers.GlobalAveragePooling2D()
    def call(self, x):
        B = tf.shape(x)[0]; gap = self.gap(x)
        gap = tf.reshape(gap, [B, 1, self.channels])
        attn = tf.sigmoid(self.conv(gap))
        return x * tf.reshape(attn, [B, 1, 1, self.channels])
    def get_config(self):
        c = super().get_config(); c["kernel_size"] = self.kernel_size; return c

class PhysicsCorrectionLayer(tf.keras.layers.Layer):
    def __init__(self, eps=0.1, blend=0.08, **kw):
        super().__init__(**kw); self.eps = eps; self.blend = blend
    def call(self, inputs):
        img, A, t = inputs
        A_bc = tf.broadcast_to(tf.reshape(A, [-1,1,1,3]), tf.shape(img))
        t_bc = tf.broadcast_to(t, tf.shape(img))
        j = tf.clip_by_value((img - A_bc) / (t_bc + self.eps) + A_bc, 0, 1)
        return img * (1 - self.blend) + j * self.blend
    def get_config(self):
        c = super().get_config(); c.update({"eps": self.eps, "blend": self.blend}); return c

def preprocess(img):
    img = np.power(np.clip(img, 0, 1), 0.9).astype(np.float32)
    for c in range(3):
        lo, hi = img[:,:,c].min(), img[:,:,c].max()
        if hi > lo + 1e-6: img[:,:,c] = (img[:,:,c] - lo) / (hi - lo)
    return np.clip(img, 0, 1).astype(np.float32)

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--model", required=True)
    parser.add_argument("--input", required=True)
    parser.add_argument("--output", default="dehazed_output.png")
    args = parser.parse_args()

    custom = {"ECABlock": ECABlock, "PhysicsCorrectionLayer": PhysicsCorrectionLayer}
    model = tf.keras.models.load_model(args.model, custom_objects=custom, compile=False)
    print(f"Model loaded: {model.count_params():,} params")

    img = cv2.imread(args.input)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE)).astype(np.float32) / 255.0
    img = preprocess(img)

    pred = model.predict(img[np.newaxis], verbose=0)[0]
    pred = np.clip(pred, 0, 1)

    out = cv2.cvtColor((pred * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)
    cv2.imwrite(args.output, out)
    print(f"Saved: {args.output}")

if __name__ == "__main__":
    main()
'''

with open(f'{SAVE_DIR}/test_offline.py', 'w') as f:
    f.write(offline_script)
print("Offline test script saved to /kaggle/working/test_offline.py")
print("Download and run: python test_offline.py --model models/stage3_final.keras --input hazy.jpg")
